# %%
import numpy as np
import pandas as pd
from core.loader import StockLoader
import matplotlib.pyplot as plt

# %%
# test pykernel
import numpy as np
print(np.__file__)
# Out:
# /Users/thang/Desktop/thang.nguyen/main_projects/lib/python3.9/site-packages/numpy/__init__.py

# %%
# get TCB price in 2022.
loader = StockLoader('2022-01-01','2022-09-21')

# %%
TCB_price = loader.load_data_of_a_symbol(symbol='TCB')
TCB_price.columns
# Out:
# Index(['index', 'code', 'date', 'time', 'floor', 'type', 'basicPrice',
#        'ceilingPrice', 'floorPrice', 'open', 'high', 'low', 'close', 'average',
#        'adOpen', 'adHigh', 'adLow', 'adClose', 'adAverage', 'nmVolume',
#        'nmValue', 'ptVolume', 'ptValue', 'change', 'adChange', 'pctChange'],
#       dtype='object')

# %%
df = TCB_price[['date', 'close']]

# %%
plt.plot(df['date'], df['close'])
